# %%
import pandas as pd
import numpy as np
import joblib
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # Levanto los features de los targets
# Previamente creados en _CalculoSC_.

# %%
test = pd.read_csv('modelos/sc/test_sc.csv')
test.head()
# Out:
#        ref_type      ref_hash  total_apps  %implicit  %attributed  \
# 0  1.891515e+18  1.000169e+18         1.0        0.0          0.0
# 1  1.891515e+18  1.000396e+18         2.0        0.5          0.0
# 2  1.891515e+18  1.003027e+18         2.0        0.5          0.0
# 3  1.494519e+18  1.006670e+18         2.0        0.5          0.0
# 4  1.891515e+18  1.007573e+18         1.0        0.0          0.0
#
#    most_freq_lang  most_freq_app         model            ip  events_%wifi  \
# 0    3.301378e+18          122.0  1.805456e+18  5.483720e+18      0.000000
# 1    6.977049e+18          121.0  8.058599e+17  6.126933e+18      1.000000
# 2    3.301378e+18           14.0  8.590181e+18  2.036110e+18      0.833333
# 3    8.441417e+18           68.0  6.794880e+18  2.799308e+18      0.333333
# 4    3.301378e+18           94.0  1.327864e+18  8.238829e+18      0.000000
#
#    event_apps  distinct_events  total_events  preds_xgb       preds_rf  \
# 0        32.0              4.0          32.0  85503.766  123334.907215
# 1         2.0              2.0           2.0  90008.850  130855.317335
# 2        54.0             10.0          54.0  84732.516  124227.002212
# 3         3.0              2.0           3.0  88227.336  128246.085354
# 4         6.0              1.0           6.0  87203.110  124216.245892
#
#       preds_bag     preds_lgbm
# 0  141436.74576  129128.675353
# 1  155127.90550  129403.401064
# 2  151171.77756  128808.094841
# 3  144818.23918  129211.800532
# 4  148322.54066  127469.656168

# %%
predictions_sc = regr.predict(test)
predictions_sc

# %%
pd.DataFrame(predictions_sc).to_csv("../output/predicciones_sc.csv", header=None, index=False)
