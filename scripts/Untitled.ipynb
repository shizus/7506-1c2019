# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
installs = pd.read_csv('/home/fede/Desktop/Datos/TPPandas/installs.csv.gzip', compression = 'gzip', dtype = {'ref_type': 'int8',
                                                                                                             'ref_hash': np.float32
                                                                                                             'device_brand': 'category',
                                                                                                             'device_model': 'category',})
auctions = pd.read_csv('/home/fede/Desktop/Datos/TPPandas/auctions.csv.gzip', compression = 'gzip', dtype = {'auction_type_id':'object', 
                                                                           'country': np.float32, 
                                                                           'date': 'object', 
                                                                           'device_id': np.float32, 
                                                                           'platform' :'int8', 
                                                                           'ref_type_id':'int8', 
                                                                           'source_id':'int8'})

# %%
events.head()
# Out:
#                       date  event_id             ref_type  \
# 0  2019-03-05 00:09:36.966         0  1891515180541284343
# 1  2019-03-05 00:09:38.920         1  1891515180541284343
# 2  2019-03-05 00:09:26.195         0  1891515180541284343
# 3  2019-03-05 00:09:31.107         2  1891515180541284343
# 4  2019-03-09 21:00:36.585         3  1891515180541284343
#
#               ref_hash application_id  attributed   device_countrycode  \
# 0  2688759737656491380             38       False  6333597102633388268
# 1  2688759737656491380             38       False  6333597102633388268
# 2  2688759737656491380             38       False  6333597102633388268
# 3  2688759737656491380             38       False  6333597102633388268
# 4  2635154697734164782             38       False  6333597102633388268
#
#        device_os_version device_brand           device_model  ... trans_id  \
# 0  5.908703034097298e+17          NaN  5.990116681709081e+18  ...      NaN
# ...

# %%
installs.head()
# Out:
#                    created  application_id             ref_type  \
# 0  2019-03-13 01:43:33.445               0  1891515180541284343
# 1  2019-03-13 04:58:35.078               0  1891515180541284343
# 2  2019-03-13 04:20:57.666               0  1891515180541284343
# 3  2019-03-13 04:20:57.698               0  1891515180541284343
# 4  2019-03-10 22:24:56.684               0  1891515180541284343
#
#               ref_hash  click_hash  attributed  implicit   device_countrycode  \
# 0  8464844987297247076         NaN       False     False  6333597102633388268
# 1  3250564871270161533         NaN       False     False  6333597102633388268
# 2  7953318831018100268         NaN       False      True  6333597102633388268
# 3  7953318831018100268         NaN       False     False  6333597102633388268
# 4  8355110941557237501         NaN       False      True  6333597102633388268
#
#    device_brand  device_model                 session_user_agent user_agent  \
# ...

# %%
eventsAndInstalls = pd.merge(events, installs, on = 'ref_hash', how = 'inner')

# %%
del eventsAndInstalls['click_hash']

# %%
eventsAndInstalls['ref_type_x'].equals(eventsAndInstalls['ref_type_y'])
# Out:
# True

# %%
del eventsAndInstalls['ref_type_x']

# %%
del eventsAndInstalls['trans_id_y']

# %%
eventsAndInstalls.dtypes
# Out:
# date                      object
# event_id                   int64
# ref_hash                   int64
# application_id_x        category
# attributed_x                bool
# device_countrycode_x    category
# device_os_version       category
# device_brand_x          category
# device_model_x          category
# device_city             category
# session_user_agent_x    category
# trans_id_x              category
# user_agent_x            category
# event_uuid_x              object
# carrier                 category
# kind_x                  category
# device_os               category
# wifi_x                  category
# connection_type         category
# ip_address_x               int64
# device_language_x       category
# created                   object
# application_id_y           int64
# ref_type_y              category
# attributed_y                bool
# implicit                    bool
# device_countrycode_y       int64
# device_brand_y           float64
# ...

# %%
eventsAndInstalls['device_language_x'].value_counts()
# Out:
# 9.0283826551012e+18       20957
# 3.3013777759776993e+18    14530
# 4.621024053086952e+18      5985
# 6.977049253562486e+18      2835
# 4.077062198952597e+17      2005
# 2.822843369618519e+17      1520
# 1.5264214271539814e+18      547
# 6.804427935983149e+18       485
# 4.060929664968129e+18       357
# 1.1932786179815933e+18      171
# 6.035179960508536e+18       165
# 3.695787044360519e+17       131
# 1.1015391524827163e+17       79
# 6.535228344298127e+18        48
# 7.77431571166467e+18         46
# 3.1772649501524695e+18       43
# 5.84621722065469e+18         42
# 3.095855928498728e+18        25
# 5.241240798510074e+17        14
# 4.594650153337342e+18         8
# 3.074903815496462e+18         8
# 5.061641824384339e+18         7
# 6.846872595739463e+18         7
# 6.782349352251195e+18         6
# 1.686906046235505e+18         6
# 6.569908124035395e+18         6
# 2.4883657416061665e+18        4
# 2.0619367645717496e+18        3
# 7.045130426125571e+18         3
# ...

# %%
eventsAndInstalls['device_language_y'].value_counts()
# Out:
# 9.028383e+18    24310
# 3.301378e+18    14676
# 4.621024e+18     6943
# 6.977049e+18     2181
# 4.077062e+17     1552
# 2.822843e+17     1543
# 1.526421e+18      635
# 4.060930e+18      253
# 1.193279e+18      241
# 6.035180e+18      144
# 3.695787e+17      143
# 1.101539e+17       93
# 7.774316e+18       74
# 6.535228e+18       48
# 3.177265e+18       43
# 5.846217e+18       42
# 3.095856e+18       40
# 1.686906e+18       18
# 2.061937e+18       11
# 4.594650e+18       10
# 3.074904e+18        8
# 6.846873e+18        7
# 5.061642e+18        7
# 6.782349e+18        6
# 6.569908e+18        6
# 2.488366e+18        4
# 7.045130e+18        3
# 5.794427e+17        2
# 3.544544e+18        2
# 4.073835e+18        1
# Name: device_language_y, dtype: int64
